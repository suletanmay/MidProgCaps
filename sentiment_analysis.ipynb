# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# %%
import pandas as pd

# Load the CSV file
file_path = 'data/cluster_recommendation.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the data
df.head()
# Out:
#   Department    age_group       tenure_group  employee_segment  \
# 0         HR      Boomers  Senior (8+ years)                 2
# 1    Finance        Gen X    New (0-2 years)                 2
# 2  Marketing      Boomers  Senior (8+ years)                 5
# 3      Sales  Millennials  Senior (8+ years)                 3
# 4    Finance        Gen X    New (0-2 years)                 2
#
#                     top1                    top2                      top3  \
# 0         Healthcare FSA  401k High Contribution  Supplemental High Amount
# 1         Healthcare FSA  401k High Contribution  Supplemental High Amount
# 2  Supplemental Standard              HMO Family     401k Maximum Matching
# 3    401k Basic Matching    401k Investment Fees    401k High Contribution
# 4         Healthcare FSA  401k High Contribution  Supplemental High Amount
#
#                           bot1                        bot2  \
# 0          On-Site Infant Care     Premium Discount Tier 1
# ...

# %%
cluster_rec_df = segment_data[['Department', 'age_group', 'tenure_group', 'employee_segment', 'top1', 'top2', 'top3', 'bot1', 'bot2', 'bot3', 'seg_rec1', 'seg_rec2', 'seg_rec3']].copy()

# %%
cluster_rec_df.to_csv('data/cluster_recommendation.csv', index=False)

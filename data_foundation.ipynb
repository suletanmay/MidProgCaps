# %%
import pandas as pd
import numpy as np

# %%
#load datasets

benefits_data = pd.read_csv('data/benefits_data.csv')
employee_data = pd.read_csv('data/employee_data.csv')
feedback_data = pd.read_csv('data/feedback_data.csv')
usage_data = pd.read_csv('data/usage_data.csv')

# %%
#data profiling

def profile_dataset(df):

    #Shape
    print("="*50)
    print(f"Dataset shape: {df.shape[0]} rows × {df.shape[1]} columns")
    print("="*50)

    #Data Type Info
    print("\n--- Data Types ---")
    print(df.dtypes)

    #Missing values
    print("\n--- Missing Values ---")
    print(df.isnull().sum()[df.isnull().sum() > 0])

    #Numerical Data Summ
    print("\n--- Numeric Columns Summary ---")
    print(df.describe().T)

    #Outlier Checks ?????????
    print("\n--- Outlier Check Using IQR ---")
    num_cols = df.select_dtypes(include=[np.number]).columns
    outliers = {}
    for col in num_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outlier_count = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
        # outliers[col] = outlier_count
        # print(outliers)
        if outlier_count > 0:
            print(f"{col}: {outliers} potential outliers")
        else:
            print(f"{col}: No significant outliers detected")

    #Categorical Data Summ
    print("\n--- Categorical Columns Summary ---")
    cat_cols = df.select_dtypes(include=['object']).columns
    for col in cat_cols:
        print(f"\nColumn: {col}")
        print(df[col].value_counts(dropna=False).head(10))  # top 10 frequent

    #Duplicate Check
    print("\n--- Duplicate Rows ---")
    dup_count = df.duplicated().sum()
    print(f"Number of duplicate rows: {dup_count}")

    #Column Cardinality
    print("\n--- Cardinality of Columns ---")
    for col in df.columns:
        print(f"{col}: {df[col].nunique()} unique values")

    return df

# %%
benefits_df = profile_dataset(benefits_data)
# Out:
# ==================================================
# Dataset shape: 30 rows × 4 columns
# ==================================================
#
# --- Data Types ---
# BenefitID           int64
# BenefitType        object
# BenefitSubType     object
# BenefitCost       float64
# dtype: object
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Numeric Columns Summary ---
#              count     mean         std   min     25%      50%       75%  \
# BenefitID     30.0   15.500    8.803408   1.0    8.25   15.500   22.7500
# BenefitCost   30.0  523.836  302.652678  65.0  277.33  514.655  779.3125
#
#                 max
# BenefitID     30.00
# BenefitCost  969.28
#
# --- Outlier Check Using IQR ---
# BenefitID: No significant outliers detected
# BenefitCost: No significant outliers detected
#
# --- Categorical Columns Summary ---
#
# Column: BenefitType
# BenefitType
# Retirement Plan              6
# Health Insurance             4
# Tuition Reimbursement        4
# Gym Membership               4
# Life Insurance               4
# Childcare                    2
# Commuter Benefits            1
# Technology Stipend           1
# Flexible Spending Account    1
# Wellness Programs            1
# Name: count, dtype: int64
#
# Column: BenefitSubType
# BenefitSubType
# 401k Basic Matching         1
# PPO Individual              1
# After-School Care           1
# Dependent Coverage          1
# 401k Maximum Matching       1
# Family Membership           1
# Supplemental Standard       1
# Tier 3 Partners             1
# Supplemental High Amount    1
# HMO Family                  1
# Name: count, dtype: int64
#
# --- Duplicate Rows ---
# Number of duplicate rows: 0
#
# --- Cardinality of Columns ---
# BenefitID: 30 unique values
# BenefitType: 12 unique values
# BenefitSubType: 30 unique values
# BenefitCost: 30 unique values

# %%
employee_df = profile_dataset(employee_data)
# Out:
# ==================================================
# Dataset shape: 5000 rows × 5 columns
# ==================================================
#
# --- Data Types ---
# EmployeeID     int64
# Age            int64
# Gender        object
# Department    object
# Tenure         int64
# dtype: object
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Numeric Columns Summary ---
#              count       mean          std   min      25%     50%      75%  \
# EmployeeID  5000.0  2500.5000  1443.520003   1.0  1250.75  2500.5  3750.25
# Age         5000.0    43.4662    12.813278  22.0    32.00    43.0    55.00
# Tenure      5000.0    12.8460     9.915863   1.0     5.00    10.0    19.00
#
#                max
# EmployeeID  5000.0
# Age           65.0
# Tenure        40.0
#
# --- Outlier Check Using IQR ---
# EmployeeID: No significant outliers detected
# Age: No significant outliers detected
# Tenure: No significant outliers detected
#
# --- Categorical Columns Summary ---
#
# Column: Gender
# Gender
# Male          2489
# Female        2413
# Non-Binary      98
# Name: count, dtype: int64
#
# Column: Department
# Department
# IT           1221
# Marketing    1034
# Finance      1022
# Sales        1011
# HR            712
# Name: count, dtype: int64
#
# --- Duplicate Rows ---
# Number of duplicate rows: 0
#
# --- Cardinality of Columns ---
# EmployeeID: 5000 unique values
# Age: 44 unique values
# Gender: 3 unique values
# Department: 5 unique values
# Tenure: 40 unique values

# %%
feedback_df = profile_dataset(feedback_data)
# Out:
# ==================================================
# Dataset shape: 30000 rows × 4 columns
# ==================================================
#
# --- Data Types ---
# EmployeeID            int64
# BenefitID             int64
# SatisfactionScore     int64
# Comments             object
# dtype: object
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Numeric Columns Summary ---
#                      count         mean          std  min     25%     50%  \
# EmployeeID         30000.0  2496.277467  1448.017411  1.0  1235.0  2504.0
# BenefitID          30000.0    15.513200     8.673062  1.0     8.0    16.0
# SatisfactionScore  30000.0     3.004300     1.420921  1.0     2.0     3.0
#
#                       75%     max
# EmployeeID         3751.0  5000.0
# BenefitID            23.0    30.0
# SatisfactionScore     4.0     5.0
#
# --- Outlier Check Using IQR ---
# EmployeeID: No significant outliers detected
# BenefitID: No significant outliers detected
# SatisfactionScore: No significant outliers detected
#
# --- Categorical Columns Summary ---
#
# Column: Comments
# Comments
# Unhappy with this benefit.             1258
# Top-notch retirement plan.             1208
# Good plan with decent returns.         1181
# Standard, nothing exceptional.         1174
# Returns are not as expected.           1171
# Generous vacation days, very happy.     875
# Not worth the hassle.                   855
# Helps but limited in scope.             840
# Good value, I enjoy the variety.        840
# Sufficient time off provided.           818
# Name: count, dtype: int64
#
# --- Duplicate Rows ---
# Number of duplicate rows: 624
#
# --- Cardinality of Columns ---
# EmployeeID: 4989 unique values
# BenefitID: 30 unique values
# SatisfactionScore: 5 unique values
# Comments: 40 unique values

# %%
usage_df = profile_dataset(usage_data)
# Out:
# ==================================================
# Dataset shape: 50000 rows × 4 columns
# ==================================================
#
# --- Data Types ---
# EmployeeID         int64
# BenefitID          int64
# UsageFrequency     int64
# LastUsedDate      object
# dtype: object
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Numeric Columns Summary ---
#                   count        mean          std  min     25%     50%     75%  \
# EmployeeID      50000.0  2513.83360  1445.499017  1.0  1263.0  2520.0  3772.0
# BenefitID       50000.0    15.49882     8.680902  1.0     8.0    16.0    23.0
# UsageFrequency  50000.0     3.34836     3.139892  0.0     0.0     3.0     5.0
#
#                    max
# EmployeeID      5000.0
# BenefitID         30.0
# UsageFrequency    10.0
#
# --- Outlier Check Using IQR ---
# EmployeeID: No significant outliers detected
# BenefitID: No significant outliers detected
# UsageFrequency: No significant outliers detected
#
# --- Categorical Columns Summary ---
#
# Column: LastUsedDate
# LastUsedDate
# 2024-02-11    170
# 2024-02-14    169
# 2024-01-15    168
# 2024-05-07    167
# 2024-02-22    166
# 2023-10-24    166
# 2024-01-20    162
# 2024-07-07    161
# 2023-09-03    160
# 2024-05-04    160
# Name: count, dtype: int64
#
# --- Duplicate Rows ---
# Number of duplicate rows: 2
#
# --- Cardinality of Columns ---
# EmployeeID: 5000 unique values
# BenefitID: 30 unique values
# UsageFrequency: 11 unique values
# LastUsedDate: 366 unique values

# %%
# from ydata_profiling import ProfileReport
# import pandas as pd
# profile = ProfileReport(benefits_data, explorative=True)
# profile.to_file("profile_report.html")

# %%
#Merge datasets using EmployeeID and BenefitID
usage_employee = pd.merge(usage_data, employee_data, on='EmployeeID', how='inner')
on_ben = pd.merge(usage_employee, benefits_data, on='BenefitID', how='inner')
merged = pd.merge(on_ben, feedback_data, on=['EmployeeID', 'BenefitID'], how='inner')

# %%
#standardize data types
#LastUsedDate --> datetime
#Gender/Department

merged['LastUsedDate'] = pd.to_datetime(merged['LastUsedDate'], errors='coerce')
merged['Gender'] = merged['Gender'].astype('category')
merged['Department'] = merged['Department'].astype('category')

# %%
merged
# Out:
#       EmployeeID  BenefitID  UsageFrequency LastUsedDate  Age  Gender  \
# 0            220         20               4   2024-05-03   64    Male
# 1           1820         26               1   2024-02-08   53    Male
# 2            285         16               2   2023-10-27   64    Male
# 3           4536          8               8   2024-07-03   32  Female
# 4           1262         12               3   2024-04-13   42    Male
# ...          ...        ...             ...          ...  ...     ...
# 9827        3106         25               0   2023-11-23   33    Male
# 9828        2588         28               5   2024-07-23   32    Male
# 9829         533         28               2   2024-01-23   56  Female
# 9830        4288         20               4   2024-04-30   49  Female
# 9831        4627         30               0   2024-06-08   31    Male
#
#      Department  Tenure            BenefitType           BenefitSubType  \
# 0            HR      35  Tuition Reimbursement     Undergraduate Degree
# 1       Finance       2         Gym Membership        Family Membership
# 2     Marketing      35       Health Insurance          HDHP Individual
# 3         Sales      10      Wellness Programs  Premium Discount Tier 1
# 4       Finance       1  Tuition Reimbursement          Graduate Degree
# ...         ...     ...                    ...                      ...
# 9827         IT      12         Life Insurance    Supplemental Standard
# 9828         IT       5         Life Insurance       Dependent Coverage
# 9829    Finance      34         Life Insurance       Dependent Coverage
# 9830    Finance      13  Tuition Reimbursement     Undergraduate Degree
# 9831         IT       9  Tuition Reimbursement       Individual Courses
#
#       BenefitCost  SatisfactionScore                            Comments
# 0          489.96                  1               Not worth the hassle.
# 1          519.66                  2       Not many locations available.
# 2           84.55                  3    Satisfactory, but could improve.
# 3          125.00                  1          Barely any time off given.
# 4          824.53                  3         Helps but limited in scope.
# ...           ...                ...                                 ...
# 9827       774.91                  1              Disappointing service.
# 9828       165.54                  4          Solid plan, happy with it.
# 9829       165.54                  2                Coverage is minimal.
# 9830       489.96                  2  Complicated reimbursement process.
# 9831       723.73                  5   Incredible support for education.
#
# [9832 rows x 13 columns]

# %%
#Create derived 
merged['age_group'] = pd.cut(merged['Age'], bins=[17, 25, 41, 57, np.inf], labels=['Gen Z', 'Millennial', 'Gen X', 'Boomer'])

merged['tenure_group'] = pd.cut(merged['Tenure'], bins=[0, 5, 15, np.inf], labels=['<5', '5-15', '>15'])

subcat_dummies = pd.get_dummies(merged['BenefitSubType'], prefix='subcat')
merged = pd.concat([merged, subcat_dummies], axis=1)

# %%
merged.columns
# Out:
# Index(['EmployeeID', 'BenefitID', 'UsageFrequency', 'LastUsedDate', 'Age',
#        'Gender', 'Department', 'Tenure', 'BenefitType', 'BenefitSubType',
#        'BenefitCost', 'SatisfactionScore', 'Comments', 'age_group',
#        'tenure_group', 'subcat_401k Basic Matching',
#        'subcat_401k Catch-Up Contributions', 'subcat_401k High Contribution',
#        'subcat_401k Investment Fees', 'subcat_401k Maximum Matching',
#        'subcat_401k Standard Matching', 'subcat_After-School Care',
#        'subcat_Basic Coverage', 'subcat_Conference Attendance',
#        'subcat_Dependent Coverage', 'subcat_Family Membership',
#        'subcat_Graduate Degree', 'subcat_HDHP Individual', 'subcat_HMO Family',
#        'subcat_Healthcare FSA', 'subcat_Individual Courses',
#        'subcat_Monthly Communications', 'subcat_Monthly Internet Allowance',
#        'subcat_On-Site Infant Care', 'subcat_PPO Family',
#        'subcat_PPO Individual', 'subcat_Premium Discount Tier 1',
#        'subcat_Professional Certification', 'subcat_Supplemental High Amount',
#        'subcat_Supplemental Standard', 'subcat_Tier 1 Partners',
#        'subcat_Tier 2 Partners', 'subcat_Tier 3 Partners',
#        'subcat_Transit Subsidy', 'subcat_Undergraduate Degree'],
#       dtype='object')

# %%
#Data Validation
#drop duplicates based on employee and benefit id
merged = merged.drop_duplicates(subset=['EmployeeID', 'BenefitID'], keep='first')

#no neg usageFrequency values
merged = merged[merged['UsageFrequency'] >= 0]

#satisfactionScore in between 1 and 5
merged = merged[(merged['SatisfactionScore'] >=1) & (merged['SatisfactionScore'] <=5)]

# of age employees
merged = merged[merged['Age'] >= 18]

# %%
merged.to_csv('data/cleaned_data.csv', index=False)

profile_dataset(merged)
# Out:
# ==================================================
# Dataset shape: 7626 rows × 45 columns
# ==================================================
#
# --- Data Types ---
# EmployeeID                                     int64
# BenefitID                                      int64
# UsageFrequency                                 int64
# LastUsedDate                          datetime64[ns]
# Age                                            int64
# Gender                                      category
# Department                                  category
# Tenure                                         int64
# BenefitType                                   object
# BenefitSubType                                object
# BenefitCost                                  float64
# SatisfactionScore                              int64
# Comments                                      object
# age_group                                   category
# tenure_group                                category
# subcat_401k Basic Matching                      bool
# subcat_401k Catch-Up Contributions              bool
# subcat_401k High Contribution                   bool
# subcat_401k Investment Fees                     bool
# subcat_401k Maximum Matching                    bool
# subcat_401k Standard Matching                   bool
# subcat_After-School Care                        bool
# subcat_Basic Coverage                           bool
# subcat_Conference Attendance                    bool
# subcat_Dependent Coverage                       bool
# subcat_Family Membership                        bool
# subcat_Graduate Degree                          bool
# subcat_HDHP Individual                          bool
# subcat_HMO Family                               bool
# subcat_Healthcare FSA                           bool
# subcat_Individual Courses                       bool
# subcat_Monthly Communications                   bool
# subcat_Monthly Internet Allowance               bool
# subcat_On-Site Infant Care                      bool
# subcat_PPO Family                               bool
# subcat_PPO Individual                           bool
# subcat_Premium Discount Tier 1                  bool
# subcat_Professional Certification               bool
# subcat_Supplemental High Amount                 bool
# subcat_Supplemental Standard                    bool
# subcat_Tier 1 Partners                          bool
# subcat_Tier 2 Partners                          bool
# subcat_Tier 3 Partners                          bool
# subcat_Transit Subsidy                          bool
# subcat_Undergraduate Degree                     bool
# dtype: object
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Numeric Columns Summary ---
#                     count                           mean                  min  \
# EmployeeID         7626.0                    2512.168896                  2.0
# BenefitID          7626.0                      15.467873                  1.0
# UsageFrequency     7626.0                       3.353527                  0.0
# LastUsedDate         7626  2024-02-03 04:54:00.283241472  2023-08-05 00:00:00
# Age                7626.0                      43.544715                 22.0
# Tenure             7626.0                      12.954104                  1.0
# BenefitCost        7626.0                     523.983967                 65.0
# SatisfactionScore  7626.0                       3.014818                  1.0
#
#                                    25%                  50%  \
# EmployeeID                      1253.0               2541.0
# BenefitID                          8.0                 16.0
# UsageFrequency                     0.0                  3.0
# LastUsedDate       2023-11-04 00:00:00  2024-02-04 12:00:00
# Age                               32.0                 44.0
# Tenure                             5.0                 10.0
# BenefitCost                     261.44               509.65
# SatisfactionScore                  2.0                  3.0
#
#                                    75%                  max          std
# EmployeeID                      3761.0               5000.0  1449.926071
# BenefitID                         23.0                 30.0     8.654434
# UsageFrequency                     5.0                 10.0      3.13493
# LastUsedDate       2024-05-04 18:00:00  2024-08-04 00:00:00          NaN
# Age                               55.0                 65.0    12.846806
# Tenure                            19.0                 40.0    10.037346
# BenefitCost                     780.78               969.28   293.062704
# SatisfactionScore                  4.0                  5.0     1.416036
#
# --- Outlier Check Using IQR ---
# EmployeeID: No significant outliers detected
# BenefitID: No significant outliers detected
# UsageFrequency: No significant outliers detected
# Age: No significant outliers detected
# Tenure: No significant outliers detected
# BenefitCost: No significant outliers detected
# SatisfactionScore: No significant outliers detected
#
# --- Categorical Columns Summary ---
#
# Column: BenefitType
# BenefitType
# Retirement Plan              1516
# Tuition Reimbursement        1094
# Gym Membership               1040
# Life Insurance                983
# Health Insurance              980
# Childcare                     476
# Professional Development      267
# Flexible Spending Account     266
# Wellness Programs             262
# Commuter Benefits             260
# Name: count, dtype: int64
#
# Column: BenefitSubType
# BenefitSubType
# Undergraduate Degree       313
# 401k Standard Matching     282
# Tier 3 Partners            277
# Graduate Degree            273
# Conference Attendance      267
# 401k High Contribution     266
# Individual Courses         266
# Healthcare FSA             266
# Premium Discount Tier 1    262
# Family Membership          262
# Name: count, dtype: int64
#
# Column: Comments
# Comments
# Unhappy with this benefit.             327
# Returns are not as expected.           306
# Standard, nothing exceptional.         299
# Top-notch retirement plan.             294
# Good plan with decent returns.         290
# Helps but limited in scope.            245
# Generous vacation days, very happy.    226
# Incredible support for education.      224
# Not worth the hassle.                  223
# Fantastic benefit! I use it daily.     217
# Name: count, dtype: int64
#
# --- Duplicate Rows ---
# Number of duplicate rows: 0
#
# --- Cardinality of Columns ---
# EmployeeID: 3951 unique values
# BenefitID: 30 unique values
# UsageFrequency: 11 unique values
# LastUsedDate: 366 unique values
# Age: 44 unique values
# Gender: 3 unique values
# Department: 5 unique values
# Tenure: 40 unique values
# BenefitType: 12 unique values
# BenefitSubType: 30 unique values
# BenefitCost: 30 unique values
# SatisfactionScore: 5 unique values
# Comments: 40 unique values
# age_group: 4 unique values
# tenure_group: 3 unique values
# subcat_401k Basic Matching: 2 unique values
# subcat_401k Catch-Up Contributions: 2 unique values
# subcat_401k High Contribution: 2 unique values
# subcat_401k Investment Fees: 2 unique values
# subcat_401k Maximum Matching: 2 unique values
# subcat_401k Standard Matching: 2 unique values
# subcat_After-School Care: 2 unique values
# subcat_Basic Coverage: 2 unique values
# subcat_Conference Attendance: 2 unique values
# subcat_Dependent Coverage: 2 unique values
# subcat_Family Membership: 2 unique values
# subcat_Graduate Degree: 2 unique values
# subcat_HDHP Individual: 2 unique values
# subcat_HMO Family: 2 unique values
# subcat_Healthcare FSA: 2 unique values
# subcat_Individual Courses: 2 unique values
# subcat_Monthly Communications: 2 unique values
# subcat_Monthly Internet Allowance: 2 unique values
# subcat_On-Site Infant Care: 2 unique values
# subcat_PPO Family: 2 unique values
# subcat_PPO Individual: 2 unique values
# subcat_Premium Discount Tier 1: 2 unique values
# subcat_Professional Certification: 2 unique values
# subcat_Supplemental High Amount: 2 unique values
# subcat_Supplemental Standard: 2 unique values
# subcat_Tier 1 Partners: 2 unique values
# subcat_Tier 2 Partners: 2 unique values
# subcat_Tier 3 Partners: 2 unique values
# subcat_Transit Subsidy: 2 unique values
# subcat_Undergraduate Degree: 2 unique values
#       EmployeeID  BenefitID  UsageFrequency LastUsedDate  Age  Gender  \
# 0            220         20               4   2024-05-03   64    Male
# 1           1820         26               1   2024-02-08   53    Male
# 2            285         16               2   2023-10-27   64    Male
# 3           4536          8               8   2024-07-03   32  Female
# 4           1262         12               3   2024-04-13   42    Male
# ...          ...        ...             ...          ...  ...     ...
# 9827        3106         25               0   2023-11-23   33    Male
# 9828        2588         28               5   2024-07-23   32    Male
# 9829         533         28               2   2024-01-23   56  Female
# 9830        4288         20               4   2024-04-30   49  Female
# 9831        4627         30               0   2024-06-08   31    Male
#
#      Department  Tenure            BenefitType           BenefitSubType  ...  \
# 0            HR      35  Tuition Reimbursement     Undergraduate Degree  ...
# 1       Finance       2         Gym Membership        Family Membership  ...
# 2     Marketing      35       Health Insurance          HDHP Individual  ...
# 3         Sales      10      Wellness Programs  Premium Discount Tier 1  ...
# 4       Finance       1  Tuition Reimbursement          Graduate Degree  ...
# ...         ...     ...                    ...                      ...  ...
# 9827         IT      12         Life Insurance    Supplemental Standard  ...
# 9828         IT       5         Life Insurance       Dependent Coverage  ...
# 9829    Finance      34         Life Insurance       Dependent Coverage  ...
# 9830    Finance      13  Tuition Reimbursement     Undergraduate Degree  ...
# 9831         IT       9  Tuition Reimbursement       Individual Courses  ...
#
#       subcat_PPO Individual  subcat_Premium Discount Tier 1  \
# 0                     False                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                            True
# 4                     False                           False
# ...                     ...                             ...
# 9827                  False                           False
# 9828                  False                           False
# 9829                  False                           False
# 9830                  False                           False
# 9831                  False                           False
#
#      subcat_Professional Certification subcat_Supplemental High Amount  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
# ...                                ...                             ...
# 9827                             False                           False
# 9828                             False                           False
# 9829                             False                           False
# 9830                             False                           False
# 9831                             False                           False
#
#      subcat_Supplemental Standard  subcat_Tier 1 Partners  \
# 0                           False                   False
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 9827                         True                   False
# 9828                        False                   False
# 9829                        False                   False
# 9830                        False                   False
# 9831                        False                   False
#
#       subcat_Tier 2 Partners  subcat_Tier 3 Partners  subcat_Transit Subsidy  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
# ...                      ...                     ...                     ...
# 9827                   False                   False                   False
# 9828                   False                   False                   False
# 9829                   False                   False                   False
# 9830                   False                   False                   False
# 9831                   False                   False                   False
#
#       subcat_Undergraduate Degree
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 9827                        False
# 9828                        False
# 9829                        False
# 9830                         True
# 9831                        False
#
# [7626 rows x 45 columns]
